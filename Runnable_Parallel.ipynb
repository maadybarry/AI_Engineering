# %%
# %load_ext dotenv
# %dotenv

# %%
from langchain_openai import ChatOpenAI

from langchain.prompts import ChatPromptTemplate

from langchain_core.runnables import RunnableParallel
from langchain_core.output_parsers import StrOutputParser

from langchain.globals import set_verbose

# %%
set_verbose(True)

# %%
llm = ChatOpenAI(
    model='gpt-4o-mini',
    temperature=0,
    seed=10,
    max_completion_tokens=500
)

str_parser = StrOutputParser()

# %%
chain_template_a = ChatPromptTemplate.from_template(template='''
You are an expert in AI Engineering and Development, can you please tell me what is {framework} used for ?
''') | llm | str_parser

chain_template_b = ChatPromptTemplate.from_template(template='''
What are other popular tools other than {framework} used in AI Engineering and Development ?
''') | llm | str_parser

# %%
runnable_p = RunnableParallel(chat_a = chain_template_a, chat_b = chain_template_b)

# %%
runnable_p.invoke({'framework':'langchain'})
# Out:
# {'chat_a': 'LangChain is a framework designed to facilitate the development of applications that utilize large language models (LLMs). It provides a structured way to build applications that can leverage the capabilities of LLMs for various tasks, such as natural language understanding, text generation, and conversational agents. Here are some key features and use cases of LangChain:\n\n1. **Chain of Thought**: LangChain allows developers to create chains of operations that can include multiple steps, such as querying a database, processing the results, and generating a response using an LLM.\n\n2. **Integration with External Data Sources**: It can connect to various data sources, such as APIs, databases, and other services, enabling applications to pull in real-time data and enhance the responses generated by LLMs.\n\n3. **Prompt Management**: LangChain provides tools for managing and optimizing prompts, which are crucial for getting the best performance from LLMs. This includes prompt templates and strategies for dynamic prompt generation.\n\n4. **Memory Management**: The framework can maintain context over multiple interactions, which is essential for building conversational agents that need to remember previous interactions.\n\n5. **Tooling and Utilities**: LangChain includes various utilities for common tasks, such as text splitting, summarization, and more, making it easier to build complex applications.\n\n6. **Use Cases**: Common applications built with LangChain include chatbots, virtual assistants, content generation tools, question-answering systems, and more.\n\nOverall, LangChain streamlines the process of building applications that harness the power of LLMs, making it easier for developers to create sophisticated AI-driven solutions.',
#  'chat_b': "In the field of AI engineering and development, there are several popular tools and frameworks that are widely used alongside or instead of LangChain. Here are some notable ones:\n\n1. **TensorFlow**: An open-source machine learning framework developed by Google, widely used for building and training deep learning models.\n\n2. **PyTorch**: An open-source machine learning library developed by Facebook's AI Research lab, known for its flexibility and ease of use, especially in research.\n\n3. **Hugging Face Transformers**: A library that provides pre-trained models for natural language processing (NLP) tasks, making it easier to implement state-of-the-art models.\n\n4. **Keras**: A high-level neural networks API, written in Python and capable of running on top of TensorFlow, making it easier to build and train deep learning models.\n\n5. **Scikit-learn**: A popular library for classical machine learning algorithms, providing simple and efficient tools for data mining and data analysis.\n\n6. **FastAPI**: A modern web framework for building APIs with Python, often used to deploy machine learning models as web services.\n\n7. **Streamlit**: An open-source app framework for Machine Learning and Data Science projects, allowing developers to create interactive web applications easily.\n\n8. **Flask**: A lightweight web framework for Python, often used to create web applications and APIs for deploying machine learning models.\n\n9. **Django**: A high-level Python web framework that encourages rapid development and clean, pragmatic design, often used for building complex web applications.\n\n10. **OpenAI API**: Provides access to powerful language models and other AI capabilities, allowing developers to integrate advanced AI features into their applications.\n\n11. **Ray**: A framework for building and running distributed applications, often used for scaling machine learning workloads.\n\n12. **MLflow**: An open-source platform for managing the machine learning lifecycle, including experimentation, reproducibility, and deployment.\n\n13. **Kubeflow**: A machine learning toolkit for Kubernetes, designed to make it easy to deploy and manage machine learning workflows on Kubernetes.\n\n14. **Weights & Biases**: A tool for tracking experiments, visualizing results, and collaborating on machine learning projects.\n\n15. **DataRobot**: An automated machine learning platform that helps data scientists and business analysts build and deploy predictive models.\n\nThese tools cater to various aspects of AI development, from model training and deployment to data management and experimentation tracking. The"}

# %%
#runnable_p.get_graph().print_ascii()

# %%
chain_template_t = ChatPromptTemplate.from_template(template='''
I am a intermediate programmer, could you tell me how long it will take to {chat_a} and other tools such as {chat_b} to master ?
''')

# %%
final_chain = ({'chat_a' : chain_template_a, 'chat_b' : chain_template_b} | chain_template_t | llm | str_parser)

# %%
final_chain.invoke({'framework':'langchain'})
# Out:
# "The time it takes to learn and effectively use LangChain, along with the other tools and frameworks you've mentioned, can vary significantly based on several factors, including your current skill level, the complexity of the projects you want to undertake, and the amount of time you can dedicate to learning. Here’s a rough breakdown of what you might expect:\n\n### Learning LangChain\n\n1. **Basic Understanding (1-2 weeks)**:\n   - Familiarize yourself with the core concepts of LangChain, such as chains of operations, prompt management, and memory management.\n   - Explore the documentation and tutorials provided by the LangChain community.\n\n2. **Intermediate Proficiency (2-4 weeks)**:\n   - Start building simple applications using LangChain, such as a basic chatbot or a text generation tool.\n   - Experiment with integrating external data sources and managing prompts effectively.\n\n3. **Advanced Usage (1-2 months)**:\n   - Work on more complex applications that utilize LangChain’s agent framework and memory management features.\n   - Dive deeper into optimizing performance and handling real-world scenarios.\n\n### Learning Other Tools and Frameworks\n\n1. **TensorFlow/PyTorch (1-2 months)**:\n   - If you are new to deep learning, expect to spend time learning the fundamentals of neural networks and how to use these frameworks for model training and deployment.\n\n2. **Hugging Face Transformers (1-2 weeks)**:\n   - This library is relatively straightforward to use, especially if you have a basic understanding of NLP. You can quickly get started with pre-trained models.\n\n3. **FastAPI/Flask (1-2 weeks)**:\n   - Learning to build APIs with FastAPI or Flask can be done relatively quickly, especially if you have prior experience with web development.\n\n4. **MLflow/Kubeflow (2-4 weeks)**:\n   - These tools can take longer to master, especially if you are new to managing machine learning workflows and deployments.\n\n5. **Data Analysis Libraries (Scikit-learn, Pandas) (1-2 weeks)**:\n   - If you are familiar with Python, learning these libraries for data analysis and classical machine learning can be quick.\n\n### Overall Timeline\n\n- **Total Time Estimate**: If you dedicate a few hours each week, you might expect to spend anywhere from **3 to 6 months** to become proficient in LangChain and the associated tools, depending on your prior experience and the complexity of the projects you want"

# %%
final_chain.get_graph().print_ascii()
# Out:
#              +------------------------------+
#              | Parallel<chat_a,chat_b>Input |
#              +------------------------------+
#                    ***               ***
#                 ***                     ***
#               **                           **
# +--------------------+              +--------------------+
# | ChatPromptTemplate |              | ChatPromptTemplate |
# +--------------------+              +--------------------+
#            *                                   *
#            *                                   *
#            *                                   *
#     +------------+                      +------------+
#     | ChatOpenAI |                      | ChatOpenAI |
#     +------------+                      +------------+
#            *                                   *
#            *                                   *
#            *                                   *
#   +-----------------+                 +-----------------+
#   | StrOutputParser |                 | StrOutputParser |
#   +-----------------+                 +-----------------+
#                    ***               ***
#                       ***         ***
#                          **     **
#             +-------------------------------+
#             | Parallel<chat_a,chat_b>Output |
#             +-------------------------------+
#                              *
#                              *
#                              *
#                   +--------------------+
#                   | ChatPromptTemplate |
#                   +--------------------+
#                              *
#                              *
#                              *
#                       +------------+
#                       | ChatOpenAI |
#                       +------------+
#                              *
#                              *
#                              *
#                     +-----------------+
#                     | StrOutputParser |
#                     +-----------------+
#                              *
#                              *
#                              *
#                 +-----------------------+
#                 | StrOutputParserOutput |
#                 +-----------------------+
